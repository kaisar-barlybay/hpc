# %%
import pandas as pd

# %%
f = open('HV15R.mtx', 'r')

# %%
for i in range(100):
    print(f.readline())
# Out:
# %%MatrixMarket matrix coordinate real general
#
# %-------------------------------------------------------------------------------
#
# % UF Sparse Matrix Collection, Tim Davis
#
# % http://www.cise.ufl.edu/research/sparse/matrices/Fluorem/HV15R
#
# % name: Fluorem/HV15R
#
# % [HV15R: 3D engine fan. F. Pacull, Lyon, France]
#
# % id: 2384
#
# % date: 2011
#
# % author: F. Pacull
#
# % ed: T. Davis
#
# % fields: name title A b id date author ed kind notes x
#
# % kind: computational fluid dynamics problem
#
# %-------------------------------------------------------------------------------
#
# % notes:
#
# % CFD matrices from Francois Pacull, FLUOREM, in Lyon, France
#
# %
#
# % We are dealing with CFD and more precisely steady flow
#
# % parametrization. The equations involved are the compressible
#
# % Navier-Stokes ones (RANS).  These matrices are real, square and
#
# % indefinite, they correspond to the Jacobian with respect the
#
# ...
